# %% [markdown]
# # Robot Simulation Environment - Tutorial
#
# This notebook demonstrates the key features of the Robot Simulation Environment for path planning and navigation research.
#
# ## ⚠️ Safety Warning
# This simulation is for **RESEARCH AND EDUCATION PURPOSES ONLY**. Do not use on real robots without expert review and safety measures.
